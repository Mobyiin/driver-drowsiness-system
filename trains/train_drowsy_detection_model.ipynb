# %% [markdown]
# ### Install Required Libraries

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ###  Download Dataset
# You can access and download the dataset directly from Roboflow Universe:
# [Driver Drowsiness System Dataset on Roboflow](https://universe.roboflow.com/mobin-yaghooti/driver-drowsiness-system)

# %% [markdown]
# ### Train YOLOv8 Model On Custom Dataset

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data="/content/Driver-Drowsiness-System-1/data.yaml",
    epochs=50,
    imgsz=640,
    plots=True
)
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files

files.download('/content/runs/detect/train/weights/best.pt')
